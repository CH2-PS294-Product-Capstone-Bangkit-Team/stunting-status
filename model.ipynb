# %%
# Impor library yang diperlukan
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
# Memuat data dari file CSV
file_path = 'StuntedAssessmentParameters.csv'  # Ganti 'path_to_your_csv_file.csv' dengan path file CSV Anda
df = pd.read_csv(file_path)
df.head(10)
# Out:
#    Day  Severly Stunted  Moderately Stunted min  Moderately Stunted max  \
# 0    0           43.560                  43.560                  45.422
# 1    1           43.720                  43.720                  45.585
# 2    2           43.880                  43.880                  45.748
# 3    3           44.038                  44.038                  45.910
# 4    4           44.199                  44.199                  46.074
# 5    5           44.359                  44.359                  46.237
# 6    6           44.519                  44.519                  46.400
# 7    7           44.680                  44.680                  46.563
# 8    8           44.840                  44.840                  46.726
# 9    9           45.001                  45.001                  46.890
#
#    Normal Gender
# 0  45.422   Girl
# 1  45.585   Girl
# 2  45.748   Girl
# 3  45.910   Girl
# 4  46.074   Girl
# 5  46.237   Girl
# 6  46.400   Girl
# 7  46.563   Girl
# 8  46.726   Girl
# 9  46.890   Girl

# %%
#ini comen
